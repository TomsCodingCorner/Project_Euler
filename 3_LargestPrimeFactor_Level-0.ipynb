# %% [markdown]
# ![Headline](img/3.png)

# %%
print(4**0.5)
# Out:
# 2.0

# %%
import math
def find_prime(limit = 600851475143):
    for i in range(limit):
        possible_primes = []
        for poss in range(math.ceil(i**0.5)): #Yeah i know i couldve used math.sqrt() i want to be extra ;)
            possible_primes.append(maxcheck)
