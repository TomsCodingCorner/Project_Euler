# %% [markdown]
# Start date: 23-3-2026
# Completion date: 23-3-2026

# %% [markdown]
# ![Headline](img/0.png)

# %%
def num_square(squares=343000) -> list:
    count = 0
    for i in range(1, squares):
        if i % 2:
            count += i*i
    return count

found_list = num_square()
found_list
# Out:
# 6725601166609500

# %% [markdown]
# ![Headline](img/succeeded.png)
