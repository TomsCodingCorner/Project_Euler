# %% [markdown]
# ![Headline](img/17.png)

# %% [markdown]
# One, two, three, four five, six seven, eight, nine, ten, eleven, twelf

# %%
def letter_to_length(num) -> int:


    length = 0
    one_to_12 = [3,3,5,4,4,3,5,5,4,3,6,5]
    #twenty thirty fourty fifty sixty seventy eighty ninety
    twenty_to_90 = [6,6,6,5,5,7,6,6]
    #Hundrerd threehundred fourhundred, fivehundrerd, sixhundrerd, sevenhundred, eighthundrerd, ninehundrerd
    hundrerd_to_nine_hundrerd = []


    if str(num)[-2:]:
        if str(num)[-2:] != str(00) == 00:
            pass
        elif int(str(num)[-2:]) < 13 and str(num)[-2:] != str(00):
            length += one_to_12[int(str(num)[-2:])-2]

        else:
            length += twenty_to_90[int(str(num)[-2])-2]
            length += one_to_12[int(str(num)[-1])-1]

    return length

print(letter_to_length(1)) # 3
print(letter_to_length(2)) # 3
print(letter_to_length(3)) # 5

print(letter_to_length(12)) # 6
print(letter_to_length(32)) # 9
print(letter_to_length(88)) # 11
# Out:
# 5
# 3
# 3
# 6
# 9
# 11
