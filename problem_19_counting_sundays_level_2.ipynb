# %% [markdown]
# ![Headline](img/19.png)

# %% [markdown]
# I made a start, gpt made a finish... (Coaches dont play)

# %%
def is_leap_year(year):
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)


def days_in_month(month, year):
    # month: 1 = January, ..., 12 = December
    if month == 2:
        return 29 if is_leap_year(year) else 28
    if month in [4, 6, 9, 11]:
        return 30
    return 31


def main():
    # 0 = Monday, 1 = Tuesday, ..., 6 = Sunday
    weekday = 0  # 1 Jan 1900 was Monday
    count = 0
    for year in range(1900, 2001):
        for month in range(1, 13):
            # Count Sundays only during the twentieth century
            if year >= 1901 and weekday == 6:
                count += 1
            # Move to the first day of the next month
            weekday = (weekday + days_in_month(month, year)) % 7
    return count


print(main())
# Out:
# 171

# %% [markdown]
# ![Headline](img/succeeded.png)
